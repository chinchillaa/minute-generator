# %%
# !pip list
# Out:
# Package                  Version
# ------------------------ -----------
# aiohappyeyeballs         2.4.0
# aiohttp                  3.10.5
# aiosignal                1.3.1
# annotated-types          0.7.0
# anyio                    4.4.0
# asttokens                2.4.1
# async-timeout            4.0.3
# attrs                    24.2.0
# certifi                  2024.8.30
# charset-normalizer       3.3.2
# comm                     0.2.2
# debugpy                  1.8.5
# decorator                5.1.1
# distro                   1.9.0
# exceptiongroup           1.2.2
# executing                2.1.0
# ffmpeg                   1.4
# filelock                 3.16.0
# frozenlist               1.4.1
# fsspec                   2024.9.0
# h11                      0.14.0
# httpcore                 1.0.5
# httpx                    0.27.2
# idna                     3.9
# importlib_metadata       8.5.0
# ipykernel                6.29.5
# ipython                  8.18.1
# ...

# %%
# !pip install streamlit
# Out:
# ...
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached pillow-10.4.0-cp39-cp39-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# ...
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# ...
#   Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached referencing-0.35.1-py3-none-any.whl.metadata (2.8 kB)
# ...
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 55.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 658.1/658.1 kB 60.4 MB/s eta 0:00:00
# ...
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# ...
# Using cached pillow-10.4.0-cp39-cp39-manylinux_2_28_x86_64.whl (4.5 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 65.4 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 59.4 MB/s eta 0:00:00
# ...
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# ...

# %%
# !streamlit hello
# Out:
# ...
#
#
#   Welcome to Streamlit. Check out our demo in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://192.168.0.12:8501
#   External URL: http://59.129.230.147:8501
#
#   Ready to create your own Python apps super quickly?
#   Head over to https://docs.streamlit.io
#
#   May you create awesome apps!
#
#
# ^C
#   Stopping...
